# %% [markdown]
# ######
#
#
#
#
# ## Aim of This Notebook
#
# Aim of this notebook is to load and explore multi-sources datasets, prepare data for ML models, Train the regression model and return the metrics of RMSE and R_Squared, MAE. Lastly, visualize results of feature importance
#
# We developed important functions to demonstrate training model, hyperparameter tuning, etc.
#
# We choose the ML algorithms like random forest as a starting model because it can automatically return the feature importance scores.
# Other ML models will be also explored and currently in the development phase
#
# ## Data Sources
#
# Collection and Pre-processing all the datasets is one of the major components in this project.
#
# In this notebook, we used the following datasets after pre-processing (cleaning, interpolation, resampling, etc) of the raw data:
# 1. sentinel-1 InSAR coherence data products from September 2016 to November 2019,
# 2. Water Level data from EDEM gauge network
# 3. Air Temperature and wind speed
# 4. Precipitation
#
# ## Citation
# !! If you want to use our processed datasets and python codes for your research purpose, please cit our repository or the future coming paper.
#
#
# ## Future Work
#
#    Include data showing vegetation coverages in the whole Everglade region, and then conduct ML models for different vegetation areas, in order to answer the question:
#    1. How the feature importance different in different vegetation areas considering their effect on InSAR coherence variations?
#    2. What are the optimal ML models for getting the most appropriate feature importance on InSAR coherence variations? Then we have better understanding about the most importance factors contributing to the local ecosystem change?
#
#
# ###  Import all the necessary python packages

# %%
import pandas as pd
import numpy as np
import os
import xlsxwriter
#!pip install xlsxwriter

# python packages related to ML modeling
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# python packages related to model evaluation
from sklearn.metrics import r2_score  # R_2
from sklearn.metrics import mean_squared_error # RMSE
from sklearn.metrics import mean_absolute_error  # MAE

# python packages related to data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# ###  Design function randomforest_regressor to train ML model and predict target data

# %%
def randomforest_regressor(features, labels):
    # input:
    # features: datasets that are features or input of the ML model
    # labels: datasets that are target or output of the ML model
    
    # Output:
    # importances: a list of feature importances as calculated by the Random Forest Regressor
    # predictions: the predictions made by the trained model on the test data
    # train_features: the training features dataset
    # test_features: the testing features
    # train_labels: the training labels or targets
    # test_labels: the test labels or targets
    # RMSE: the calculated Root Mean Squared Error
    # R2: the calculated R-Squared
    # MAE: the calculated Mean Absolute Error
    
    # 1. Split the data into training and testing sets
    train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.3, random_state = 42)
    
    # 2. After getting the training and testing datasets, coonduct instantiate model
    # Several hyperparameters are set for the Random Forest Regressor
    rf = RandomForestRegressor(bootstrap = True,
                              max_depth = 40,
                              max_features = 3,
                              min_samples_leaf = 3,
                              min_samples_split = 7, 
                              n_estimators = 350,
                              random_state = 42)
    
    # 3. Train the model on training datasets
    rf.fit(train_features, train_labels)
    
    # 4. Test on the model and calculate the metrics
    predictions = rf.predict(test_features)
    # print(np.mean(predictions))
    
    # calculate RMSE 
    RMSE = np.sqrt(mean_squared_error(test_labels, predictions))
    
    # calculate R2
    R2 = r2_score(test_labels, predictions)
    
    # calculate MAE
    MAE = mae(test_labels, predictions) 
    
    print('Root Mean Squared Error: ', round(RMSE,2))
    
    print('R_Squared: ', round(R2,2))
    
    print('Mean Absolute Error: ', round(MAE,2))
    
    # output feature importance from the ML model
    importances = list(rf.feature_importances_)
    
    return importances, predictions, train_features, test_features, train_labels, test_labels, RMSE, R2, MAE

# %% [markdown]
# ### Design a function "importance_Visualized" to visualize the calculated feature importance from ML model

# %%
def importance_Visualized(importances, feature_list, outpathfigure, filename):
    # Input:
    # importances: a list of feature importances as calculated by the ML model
    # feature_list:
    # outpathfigure: the file path points to where you want to save the output figure representing feature importances
    # filename: the name of the figure
    
    # Output:
    # generate a figure to the file path and name specified based on input
    
    # Generate a list of tuples with variable and importance
    feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
    
    # Sort the feature importances in Descending order
    feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
    
    # Print out the feature and importances
    [print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
    
    # list of x locations for plotting, such as setting an index for each feature importance
    x_values = list(range(len(importances)))
    print(x_values)
    
    #plot features
    fig, ax = plt.subplots(1, 1, figsize=(3.5, 2.5), dpi=200)
    labels = feature_list
    x = np.arange(len(labels))  # the label indices
    
    #set the font for x,y labels in the plot
    label_font = {
        'weight': 'bold',
        'size': 8
    }
    
    #set size of title
    font={
        'weight': 'bold',
        'size': 10
    }
    
    # Set the style
    #plt.style.use('fivethirtyeight')
    
    #set color and bar width
    plt.bar(x_values, importances, color="Chocolate", width=0.4,orientation='vertical')
    
    # Make a bar chart
    #plt.bar(x_values, importances, orientation='vertical')
    
    # Tick labels for x axis
    plt.xticks(x_values, feature_list, rotation='vertical')
    
    # Axis labels and title
    plt.ylabel('Importance',label_font);
    plt.xlabel('Variable',label_font);
    plt.title('Variable Importances',font)
    
    # set parameters for tick labels
    ax.tick_params(axis='x', labelsize=6, bottom=False, labelrotation=15)
    ax.tick_params(axis='y', labelsize=6, bottom=False)
    
    ax.set_xticks(x)
    
    #turn on the grid in the figure
    plt.grid(True)
    # fill in the whole figure
    plt.tight_layout(pad=2)
    
    #output the figure that shows the feature importance calculation
    plt.savefig(outpathfigure+filename+'.png',dpi=600,bbox_inches = 'tight')

# %% [markdown]
# ## Design three functions to accomplish hyperparameter tuning
#
# ### Design a function "randomizeSearchCVdf"   for Randomized Search Cross Validation

# %%
#Tuning Hyperparameters of a Random Forest Regressor：RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

def randomizeSearchCVdf(train_features,train_labels):
    # Input:
    # train_features: The training datasets as features 
    # train_labels: The training datasets as targets or labels 
    
    # Output:
    # rf_random.best_estimator_: the best estimator found by the function, which can be used for further analysis or prediction
    
    # The values for hyperparameters are specified as lists
    
    # Number of trees in random forest
    n_estimators = [int(x) for x in np.linspace(start=300, stop=800, num=10)]
    
    # Number of features to consider at every split
    #max_features = ['auto', 'sqrt']
    max_features = ['sqrt']
    
    # Maximum number of levels in tree
    max_depth = [int(x) for x in np.linspace(50, 100, num=10)]
    max_depth.append(None)
    
    # Minimum number of samples required to split a node
    min_samples_split = [7,8,9,10]
    
    # Minimum number of samples required at each leaf node
    min_samples_leaf = [3,4,5,6]
    
    # Method of selecting samples for training each tree
    bootstrap = [True, False]

    # Create the random grid that encapsulates the range of values for each hyperparameter
    # It combines all the lists created above into a dictionary where the keys are the hyperparamter names and the values are the lists
    random_grid = {'n_estimators': n_estimators,
                   'max_features': max_features,
                   'max_depth': max_depth,
                   'min_samples_split': min_samples_split,
                   'min_samples_leaf': min_samples_leaf,
                   'bootstrap': bootstrap}
    
    # Model Intialization: An instance of 'RandomForestRegressor' is created without any specified hyperparameters
    rf = RandomForestRegressor()
    
    # Random search of parameters, using 3 fold cross validation,
    # search across 100 different combinations, and use all available cores
    # rf_random is an instance that performs the random search over the hyperparameter space for the given estimator 'rf' (RandomForestRegressor) with the specified parameter,
    # is the best set of hyperparameters that optimize the specified scoring metric
    rf_random = RandomizedSearchCV(estimator=rf, param_distributions=random_grid,
                                   n_iter=100, scoring='neg_root_mean_squared_error',
                                   cv=3, verbose=2, random_state=42, n_jobs=-1)

    # Fit the random search model, which means using the optimal ML model after random search to fit the data
    rf_random.fit(train_features, train_labels)
    
    # print the best parameters found during the search
    print(rf_random.best_params_)
    
    # returns 
    return rf_random.best_estimator_

# %% [markdown]
# ### Design another function "gridSearchCVdf' for Grid Search Cross Validation

# %%
# import the python package GridSearchCV
from sklearn.model_selection import GridSearchCV

def gridSearchCVdf(train_features,train_labels):
    # Input:
    # train_features: The training datasets as features 
    # train_labels: The training datasets as targets or labels 
    
    # Output:
    # grid_search.best_estimator_: the best estimator found by the function, which can be used for further analysis or prediction
    
    
    # Create the parameter grid based on the results of random search
    # you can run an example using random search optimization function first
    param_grid = {
        'bootstrap': [True],
        'max_depth': [20, 25, 30, 35, 40,45,50],
        'max_features': [2, 3],
        'min_samples_leaf': [3, 4, 5],
        'min_samples_split': [7, 8, 9,10],
        'n_estimators': [200,250,300,350,400,500]
    }
    
    # Create a based model
    rf = RandomForestRegressor()
    
    # Instantiate the grid search model
    grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
                               scoring='neg_root_mean_squared_error', cv=3,
                               n_jobs=-1, verbose=2)
    
    # Fit the grid search to the data
    grid_search.fit(train_features, train_labels)
    
    # print the best parameters found during the search
    print(grid_search.best_params_)
    
    return grid_search.best_estimator_

# %% [markdown]
# ### Design a function "bayesSearchCVdf" for Bayes Search Cross Validation

# %%
# import the BayesSearchCV class from the skopt library, Bayesian Optimization
# pip install scikit-optimize
from skopt import BayesSearchCV
# Define the search space for the Bayesian optimization,
# Real class is used to define continuous hyperparameters within a certain range, takes two arguments: low and high
# Integer class is used to define integer-valued hyperparameters within a certain range, takes two arguments: low and high
from skopt.space import Real, Integer

def bayesSearchCVdf(train_features, train_labels):
    # Input:
    # train_features: The training datasets as features 
    # train_labels: The training datasets as targets or labels 
    
    # Output:
    # bayes_search.best_estimator_: the best estimator found by the function, which can be used for further analysis or prediction
 
    param_space = {
        'n_estimators': (100, 1000),
        'max_depth': (10, 100),
        'min_samples_split': (2, 10),
        'min_samples_leaf': (1, 10),
        #'auto' is not a valid value for max_features
        'max_features': [ 'sqrt']
    }

    rf = RandomForestRegressor()
    
    # instantiate the bayes search model
    bayes_search = BayesSearchCV(
        estimator=rf,  
        search_spaces=param_space,  
        n_iter=100,  # number of iterations
        cv=5,       # 5-fold cross-validation
        n_jobs=-1,  # number of jobs to run in parallel
        scoring='neg_mean_squared_error',  # scoring metric
        verbose=1,
        random_state=1234
    )

    # train and fit 
    bayes_search.fit(train_features, train_labels.ravel())  # ravel()convert train_labels from 2D array to 1D array

    # best hyperparameters
    print("Best Parameters:", bayes_search.best_params_)
    
    return bayes_search.best_params_

# %% [markdown]
# ### Design function "evaluate" to detect the difference caused by hyperparameter tuning

# %%
def evaluate(model, test_features, test_labels):
    # Input:
    # model: the current selected ML model
    # test_features: the test features
    # test_labels: the test labels or targest
    
    # Output:
    # print out the RMSE and R2, MAE
    
    predictions = model.predict(test_features)
    
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(test_labels, predictions)))  
    print('R_Squared:', r2_score(test_labels, predictions))  # 
    print('Mean Absolute Error:', mean_absolute_error(test_labels, predictions))  #

# %% [markdown]
# ### Design function "predictions_Visualized" to generate figures to visualize the predictions from ML model

# %%
##Visualize the difference between actual data and predictions from the ML model
def predictions_Visualized(test_labels,predictions,outpathfigure, filename):
    # Input:
    # test_labels: actual target
    # predictions: predicted target from ML model
    # outpathfigure: the file path points to where you want to save the output figure representing feature importances
    # filename: the name of the figure
    
    # Output:
    # generate a figure to the file path and name specified based on input
    
    #set font size of fiure
    #plt.rcParams.update({'font.size': 6})
    
    fig, ax = plt.subplots(1, 1, figsize=(3, 2.5), dpi=200)
#     label_font = {
#         'weight': 'bold',
#         'size': 8
#     }
    x_axis_data=range(1,len(test_labels)+1)
    
    # plot two y values,one type is actual target, one type is predicted target
    y_axis_data1=test_labels
    y_axis_data2=predictions
    
    # 
    ax.tick_params(axis='x', labelsize=6, bottom=False, labelrotation=15)
    ax.tick_params(axis='y', labelsize=6, bottom=False)
    
    # plot
    plt.plot(x_axis_data, y_axis_data1, 'b-', alpha=1, linewidth=1, label='actual')
    plt.plot(x_axis_data, y_axis_data2, 'ro', alpha=1, linewidth=1, label='predictions',markersize='3')
    #plt.plot(x_axis_data, y_axis_data3, 'go--', alpha=0.5, linewidth=1, label='CUBIC')

    plt.legend()  # 
#     plt.xlabel('stations_number',label_font)
#     plt.ylabel('coherence',label_font)  # accuracy

    plt.xlabel('stations_number')
    plt.ylabel('coherence')

    # plt.ylim(-1,1)#
    plt.tight_layout(pad=2)
    # output
    plt.savefig(outpathfigure+filename+'.png',dpi=600,bbox_inches = 'tight')

# %% [markdown]
# ### Define a function "importance_excel" to output the calculated feature importance as dataframe for later excel file

# %%
#
def importance_excel(importances,feature_list,RMSE,R2,n,df, filename):
    # Input:
    # importances: calculated features importances
    # feature_list: list of features as input of ML model
    # RMSE: Root mean squared error
    # R2: R-squared
    # n: check whether is the first data entry
    # df: existing dataframe
    # filename: the name of excel file that store importances
    
    # Output:
    # df: modified dataframe
    
    # n == 0 means this is the first data entry
    if(n==0):
        #feature_importances = {feature: round(importance, 2) for feature, importance in zip(feature_list, importances)}
        #feature_importances['RMSE'] = RMSE
        #feature_importances['R2'] = R2
        label = feature_list
        label.append('RMSE')
        label.append('R2')
        label.append('date')
        df=pd.DataFrame(columns=label)
        print(df)
    #new row
    importances.append(RMSE)
    importances.append(R2)
    importances.append(filename)
    # add new row to end of DataFrame
    df.loc[len(df.index)] = importances
    return df

# %% [markdown]
# ### Load the pre-processed data for features from environmental variables and labels from InSAR coherence, run ML models and evaluate

# %%
if __name__ == '__main__':
    # check whether the script is being run as the main program or if it is being imported as a module into another script
    
    # set the working path of files
    path = '../../Data/'
    
    # Get all the files in the folder of Data
    fileList = os.listdir(path)
    
    #
    get_key = lambda i: i.split('.')[0]
    new_sort = sorted(fileList, key=get_key)
    print(fileList, '\n', new_sort)
    n = 0
    
    # Output working path
    # file path to store the visualization of prediction vs actual data
    outpathfigure1 = '../../Output/'
    #file path to store the visualization of feature importance, bar chart
    outpathfigure2 = '../../Output/'
    #file path to store the excel file which includes calculated feature importance
    outpathexcel = '../../Output/'
    
    # change the working path to dataframe after exploratory data analysis. 
    
    #initialize a dataframe first 
    df = pd.DataFrame()
    
    #for i in fileList:
    for i in range(len(fileList)):
    #for i in [1]:
        # get each file
        #file = new_sort[n]
        file = new_sort[i]
        
        # read the excel file and generate a dataframe
        
        features = pd.read_excel(path+file,engine='openpyxl')
        print(features.head(5))
         
        # get the filename
        filename = file.split('.', 1)[0]
        print("\n")
        print('Now Processing ：'+filename + ' Dataset')
        
        # Generate the target data
        labels = np.array(features['coherence'])
        #labels[:] = np.nan_to_num(labels)
        
        # Generate the station name
        stations_name = np.array((features['station']))
        
        # Remove the labels from the features, only remain the environmental variables for features
        features = features.drop(['coherence', 'X', 'Y', 'station','year','month','day'], axis=1)
        
        # Saving feature names for later use, save the column names
        feature_list = list(features.columns)
        
        # Convert to numpy array
        #features[:]=np.nan_to_num(features)
        features = np.array(features)

        # Random Forest Model, call the function "randomforest_regressor"
        importances, predictions, train_features, test_features, train_labels, test_labels, RMSE, R2, MAE = randomforest_regressor(
            features, labels)
        print(importances)
        
        # press ctrl + / to comment the selection of codes
        
        filenamepdViz = filename + 'pdViz'
        
        filenameimpViz = filename +'impViz'
        
        #predictions_Visualized(test_labels,predictions,outpathfigure2, filenamepdViz)
        
        importance_Visualized(importances, feature_list, outpathfigure1, filenameimpViz)
        
        df = importance_excel(importances, feature_list, RMSE, R2, n, df, filename)
        n += 1
        # save the results into a new excel file
        writer = pd.ExcelWriter(outpathexcel + filename + '_MLresults' + '.xlsx', engine='xlsxwriter')
        # options={'strings_to_urls': False})  # 
        df.to_excel(writer, index=False)
        writer._save()
        print('Done!')

    
    # Conduct Hyperparameter Tuning and evaluate the differences

#     #predictions_Visualized(labels,predictions,test_labels)
#     rf_random=randomizeSearchCVdf(train_features,train_labels)
#     evaluate(rf_random,test_features, test_labels)
# Out:
# ['DryDataAll.xlsx', 'dvalue_all_.xlsx', 'WetDataAll.xlsx']
#  ['DryDataAll.xlsx', 'WetDataAll.xlsx', 'dvalue_all_.xlsx']
#   station              X             Y  coherence  waterlevel  temperature  \
# 0   2A300  559117.217587  2.903105e+06   0.865885    -6.22846     -1.10896
# 1    3A-5  529481.312877  2.881992e+06   0.729188    -7.44424     -1.41517
# 2    3A10  525986.397592  2.906657e+06   0.958402    -6.44757     -1.24416
# 3    3A11  525611.524169  2.899888e+06   0.844378    -6.98850     -1.29713
# 4    3A12  532423.388611  2.894458e+06   0.885248    -6.76076     -1.32028
#
#    u_windpower  v_windpower  precipitation  year  month  day
# 0     5.605691     2.578178       0.000022  2016     11    2
# 1     5.598985     1.008097       0.000003  2016     11    2
# 2     5.571228     1.731338       0.000013  2016     11    2
# 3     5.578350     1.467308       0.000010  2016     11    2
# 4     5.659612     1.477017       0.000009  2016     11    2
#
#
# Now Processing ：DryDataAll Dataset
# Root Mean Squared Error:  0.2
# R_Squared:  0.35
# Mean Absolute Error:  0.14
# [0.20971281216840085, 0.1877055238277293, 0.19672934407977646, 0.19790024397956543, 0.2079520759445278]
# Variable: waterlevel           Importance: 0.21
# Variable: precipitation        Importance: 0.21
# Variable: u_windpower          Importance: 0.2
# Variable: v_windpower          Importance: 0.2
# Variable: temperature          Importance: 0.19
# [0, 1, 2, 3, 4]
# Empty DataFrame
# Columns: [waterlevel, temperature, u_windpower, v_windpower, precipitation, RMSE, R2, date]
# Index: []
# Done!
#   station              X             Y  coherence  waterlevel  temperature  \
# 0   2A300  559117.217587  2.903105e+06   0.219655    12.01453      1.41553
# 1    3A-5  529481.312877  2.881992e+06   0.913499     4.20483      1.36663
# 2    3A10  525986.397592  2.906657e+06   0.287204    12.86500      1.45475
# 3    3A11  525611.524169  2.899888e+06   0.892549     5.53904      1.45068
# 4    3A12  532423.388611  2.894458e+06   0.963816     5.96763      1.40197
#
#    u_windpower  v_windpower  precipitation  year  month  day
# 0    -1.680144    -5.822137      -0.000301  2016      9   27
# 1    -1.685898    -5.976104      -0.000566  2016      9   27
# 2    -1.692453    -5.773890      -0.000328  2016      9   27
# 3    -1.721673    -5.863188      -0.000395  2016      9   27
# 4    -1.714358    -5.927009      -0.000417  2016      9   27
#
#
# Now Processing ：WetDataAll Dataset
# Root Mean Squared Error:  0.2
# R_Squared:  0.44
# Mean Absolute Error:  0.15
# [0.2743859319032115, 0.17899932047627734, 0.2149214246569819, 0.1774359650628887, 0.1542573579006406]
# Variable: waterlevel           Importance: 0.27
# Variable: u_windpower          Importance: 0.21
# Variable: temperature          Importance: 0.18
# Variable: v_windpower          Importance: 0.18
# Variable: precipitation        Importance: 0.15
# [0, 1, 2, 3, 4]
# Done!
#   station              X             Y  coherence  waterlevel  temperature  \
# 0   2A300  559117.217587  2.903105e+06   0.219655    12.01453      1.41553
# 1    3A-5  529481.312877  2.881992e+06   0.913499     4.20483      1.36663
# 2    3A10  525986.397592  2.906657e+06   0.287204    12.86500      1.45475
# 3    3A11  525611.524169  2.899888e+06   0.892549     5.53904      1.45068
# 4    3A12  532423.388611  2.894458e+06   0.963816     5.96763      1.40197
#
#    u_component of wind  v_component of wind  precipitation  year  month  day
# 0            -1.680144            -5.822137      -0.000301  2016      9   27
# 1            -1.685898            -5.976104      -0.000566  2016      9   27
# 2            -1.692453            -5.773890      -0.000328  2016      9   27
# 3            -1.721673            -5.863188      -0.000395  2016      9   27
# 4            -1.714358            -5.927009      -0.000417  2016      9   27
#
#
# Now Processing ：dvalue_all_ Dataset
# Root Mean Squared Error:  0.2
# R_Squared:  0.41
# Mean Absolute Error:  0.15
# [0.2500268205424024, 0.18214654194446805, 0.2108007388013855, 0.17701830947286434, 0.18000758923887966]
# Variable: waterlevel           Importance: 0.25
# Variable: u_component of wind  Importance: 0.21
# Variable: temperature          Importance: 0.18
# Variable: v_component of wind  Importance: 0.18
# Variable: precipitation        Importance: 0.18
# [0, 1, 2, 3, 4]
# Done!
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=688; total time=  25.3s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=  13.2s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=744; total time=  32.7s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=  16.1s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  15.4s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=  34.5s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=411; total time=  17.3s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=522; total time=  23.7s
# [CV] END bootstrap=False, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=466; total time=  20.0s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=577; total time=  16.8s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=577; total time=  15.9s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=577; total time=  15.7s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=  13.2s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=  18.9s
# [CV] END bootstrap=False, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=  18.9s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=411; total time=  11.5s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  12.7s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=466; total time=  19.4s
# [CV] END bootstrap=False, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  14.9s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=50, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=7, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=800; total time=  35.1s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=800; total time=  33.1s
# [CV] END bootstrap=False, max_depth=72, max_features=auto, min_samples_leaf=5, min_samples_split=7, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=577; total time=  16.8s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=  18.9s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=522; total time=  22.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=688; total time=  19.2s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=688; total time=  20.3s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  14.7s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=744; total time=  33.3s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=300; total time=  12.5s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=300; total time=  12.3s
# [CV] END bootstrap=False, max_depth=61, max_features=auto, min_samples_leaf=3, min_samples_split=7, n_estimators=800; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=auto, min_samples_leaf=3, min_samples_split=7, n_estimators=800; total time=   0.0s
# [CV] END bootstrap=False, max_depth=94, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=False, max_depth=94, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=False, max_depth=94, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=88, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=88, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=88, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=800; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=800; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=800; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=577; total time=  15.5s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=466; total time=  20.4s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=522; total time=  23.4s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  23.0s
# [CV] END bootstrap=True, max_depth=50, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=True, max_depth=100, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=466; total time=  19.3s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=800; total time=  21.2s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=50, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=466; total time=  23.8s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  25.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=411; total time=  12.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=411; total time=  12.2s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=466; total time=  24.8s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=633; total time=  21.6s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=411; total time=  12.3s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  13.7s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  13.5s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=800; total time=  21.9s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=522; total time=  14.5s
# [CV] END bootstrap=False, max_depth=66, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=False, max_depth=66, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=False, max_depth=66, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=False, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=False, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=False, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=False, max_depth=83, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=False, max_depth=83, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=False, max_depth=83, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=577; total time=  18.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=  12.6s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=300; total time=  12.2s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=688; total time=  30.8s
# [CV] END bootstrap=False, max_depth=61, max_features=auto, min_samples_leaf=3, min_samples_split=7, n_estimators=800; total time=   0.0s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  13.0s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=  31.9s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  13.0s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=688; total time=  20.6s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  14.8s
# [CV] END bootstrap=False, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=7, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=7, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=7, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=94, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=94, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=94, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=577; total time=  26.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=  12.4s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=355; total time=  14.5s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=66, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=66, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=66, max_features=auto, min_samples_leaf=4, min_samples_split=7, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=744; total time=  19.2s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=  13.9s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  12.8s
# [CV] END bootstrap=False, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=  18.8s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  23.2s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=466; total time=  19.4s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=800; total time=  21.0s

# %% [markdown]
# ### Conduct Randomized Search Hyperparameter Tuning for training based on datasets "dvalue_all_"

# %%
    # Conduct RandomizedSearch Hyperparameter Tuning for training based on datasets "dvalue_all_"  
    #predictions_Visualized(labels,predictions,test_labels)
    rf_random=randomizeSearchCVdf(train_features,train_labels)
    evaluate(rf_random,test_features, test_labels)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# {'n_estimators': 522, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 77, 'bootstrap': False}
# Root Mean Squared Error: 0.19366500147712948
# R_Squared: 0.435427011527334
# Mean Absolute Error: 0.1388013436306209
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=7, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=800; total time=  36.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=355; total time=  10.3s
# [CV] END bootstrap=False, max_depth=94, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=522; total time=  21.3s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=522; total time=  23.2s
# [CV] END bootstrap=False, max_depth=83, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=False, max_depth=83, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=False, max_depth=83, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=False, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=9, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=9, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=55, max_features=auto, min_samples_leaf=3, min_samples_split=9, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=522; total time=  23.3s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=355; total time=  14.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=688; total time=  19.2s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=688; total time=  20.7s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=800; total time=  27.9s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   8.2s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=744; total time=  20.4s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=522; total time=  22.3s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=577; total time=  28.4s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=633; total time=  18.5s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  25.3s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=744; total time=  32.0s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=633; total time=  26.0s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=466; total time=  13.5s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=  18.3s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=688; total time=  28.4s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=744; total time=  31.7s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=411; total time=  17.1s
# [CV] END bootstrap=False, max_depth=94, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=577; total time=  26.6s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=  30.7s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=744; total time=  19.4s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=688; total time=  20.2s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=800; total time=  21.8s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=800; total time=  24.5s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=522; total time=  22.6s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=411; total time=  11.5s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=355; total time=  15.8s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=744; total time=  20.3s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=633; total time=  25.6s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=  16.6s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=  12.5s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=411; total time=  16.6s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=  12.6s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  11.1s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=  30.3s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=522; total time=  14.4s
# [CV] END bootstrap=False, max_depth=94, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=577; total time=  25.8s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  21.6s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  16.6s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=744; total time=  37.9s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=744; total time=  32.7s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=744; total time=  39.1s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=522; total time=  24.2s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=  17.6s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=522; total time=  23.7s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=744; total time=  18.8s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=  31.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  15.7s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=411; total time=  11.0s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=800; total time=  25.0s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=633; total time=  19.7s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  23.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=633; total time=  18.4s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=355; total time=   9.6s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=633; total time=  25.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=466; total time=  13.4s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=  18.3s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=355; total time=  10.1s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=688; total time=  18.8s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   8.2s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=744; total time=  31.7s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=522; total time=  14.5s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=577; total time=  16.8s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=633; total time=  18.2s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=  20.7s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=522; total time=  14.0s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=577; total time=  24.7s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=355; total time=  14.0s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=355; total time=  13.9s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=577; total time=  16.0s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=  18.7s
# [CV] END bootstrap=False, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=466; total time=  18.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=688; total time=  18.8s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=411; total time=  16.2s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=522; total time=  22.2s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=633; total time=  21.0s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=744; total time=  20.6s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=688; total time=  20.2s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=800; total time=  22.0s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  10.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=   8.9s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=355; total time=   9.6s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=522; total time=  22.7s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=522; total time=  13.8s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=411; total time=  11.9s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=800; total time=  21.5s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=355; total time=  15.3s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=522; total time=  14.5s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=744; total time=  29.4s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   8.5s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  11.2s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  11.1s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=688; total time=  20.0s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=688; total time=  27.1s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  14.9s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=744; total time=  20.4s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=355; total time=  10.1s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  16.5s
# [CV] END bootstrap=False, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=466; total time=  23.8s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  25.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=411; total time=  12.1s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=744; total time=  35.3s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=633; total time=  21.7s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=True, max_depth=77, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=True, max_depth=72, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=72, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=72, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=411; total time=  12.4s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=633; total time=  17.5s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=522; total time=  23.0s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=800; total time=  27.3s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=744; total time=  22.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=355; total time=  10.4s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=355; total time=  17.2s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=577; total time=  31.0s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=800; total time=  40.6s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=355; total time=  17.6s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=800; total time=  25.1s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=522; total time=  22.5s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=411; total time=  12.5s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=  13.4s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=688; total time=  30.1s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=  22.5s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=522; total time=  14.8s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=411; total time=  17.9s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  16.6s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=744; total time=  22.1s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=355; total time=  10.8s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=  12.9s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=744; total time=  33.9s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=800; total time=  32.8s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=800; total time=  34.9s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=  31.7s
# [CV] END bootstrap=True, max_depth=72, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=466; total time=   0.0s
# [CV] END bootstrap=True, max_depth=72, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=466; total time=   0.0s
# [CV] END bootstrap=True, max_depth=72, max_features=auto, min_samples_leaf=6, min_samples_split=9, n_estimators=466; total time=   0.0s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=  16.6s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=522; total time=  21.7s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=800; total time=  26.8s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=744; total time=  21.4s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=355; total time=   9.9s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=  14.3s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=411; total time=  11.2s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=800; total time=  26.4s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=688; total time=  30.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=522; total time=  14.3s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=688; total time=  19.2s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=355; total time=   9.8s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=633; total time=  18.2s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=633; total time=  18.7s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=  18.2s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=355; total time=  10.0s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=744; total time=  22.2s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=744; total time=  21.3s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=522; total time=  13.9s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=688; total time=  28.4s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  14.9s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  21.9s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  16.6s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=522; total time=  14.1s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=577; total time=  24.8s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=8, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=77, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=466; total time=   0.0s
# [CV] END bootstrap=False, max_depth=77, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=466; total time=   0.0s
# [CV] END bootstrap=False, max_depth=77, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=466; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=688; total time=  29.2s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=688; total time=  29.4s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=355; total time=  13.9s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=633; total time=  16.5s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  12.2s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=688; total time=  19.8s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=633; total time=  20.7s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   8.8s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=633; total time=  20.6s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=522; total time=  23.7s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=800; total time=  28.8s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=355; total time=  10.4s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=522; total time=  25.6s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  12.3s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=688; total time=  20.8s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=466; total time=  22.0s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=522; total time=  22.0s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=  13.2s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=  18.9s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=522; total time=  22.9s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=688; total time=  21.6s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=355; total time=  15.4s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=577; total time=  25.7s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   8.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=633; total time=  19.1s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=  21.1s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=577; total time=  17.1s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=633; total time=  19.5s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=355; total time=  15.4s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=  15.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=  10.4s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=633; total time=  18.4s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=577; total time=  19.1s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=522; total time=  14.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=744; total time=  20.5s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=466; total time=  19.3s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=522; total time=  21.0s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=744; total time=  30.0s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=744; total time=  22.0s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=  21.2s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=  31.0s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=577; total time=  17.1s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  15.0s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=355; total time=  10.3s
# [CV] END bootstrap=False, max_depth=94, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=633; total time=  25.8s
# [CV] END bootstrap=False, max_depth=66, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=688; total time=  29.5s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=522; total time=  21.9s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=  14.3s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  10.7s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=633; total time=  17.3s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=577; total time=  17.7s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  13.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=633; total time=  17.8s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=  21.5s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=522; total time=  21.6s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=  17.3s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=411; total time=  11.3s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=688; total time=  19.1s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=522; total time=  23.5s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=577; total time=  15.7s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=522; total time=  14.5s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=577; total time=  16.8s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   8.7s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  21.6s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=  20.3s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=False, max_depth=50, max_features=auto, min_samples_leaf=3, min_samples_split=8, n_estimators=522; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=7, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=True, max_depth=66, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=55, max_features=auto, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=800; total time=  35.8s
# [CV] END bootstrap=False, max_depth=72, max_features=auto, min_samples_leaf=5, min_samples_split=7, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=False, max_depth=72, max_features=auto, min_samples_leaf=5, min_samples_split=7, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=355; total time=  10.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=355; total time=  10.1s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=744; total time=  19.8s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=744; total time=  21.0s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=633; total time=  19.1s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  23.2s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=411; total time=  16.5s
# [CV] END bootstrap=True, max_depth=83, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=83, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=83, max_features=auto, min_samples_leaf=6, min_samples_split=10, n_estimators=688; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=9, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=True, max_depth=83, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=True, max_depth=83, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=True, max_depth=83, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=   0.0s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=688; total time=  19.7s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=744; total time=  18.6s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=  31.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  15.5s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=411; total time=  11.1s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=800; total time=  24.6s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=688; total time=  28.7s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  13.3s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=744; total time=  32.5s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=633; total time=  18.2s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=522; total time=  14.7s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=411; total time=  12.0s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=411; total time=  11.3s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=688; total time=  28.6s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=522; total time=  23.2s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=522; total time=  13.9s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=688; total time=  27.7s
# [CV] END bootstrap=False, max_depth=66, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=  30.9s
# [CV] END bootstrap=False, max_depth=94, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=633; total time=  25.5s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=688; total time=  20.1s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=577; total time=  16.3s
# [CV] END bootstrap=False, max_depth=94, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=False, max_depth=94, max_features=auto, min_samples_leaf=4, min_samples_split=8, n_estimators=577; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=50, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=411; total time=   0.0s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=577; total time=  15.6s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=744; total time=  29.5s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=744; total time=  30.0s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=522; total time=  22.2s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=  16.6s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=522; total time=  21.6s
# [CV] END bootstrap=False, max_depth=100, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=100, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=False, max_depth=100, max_features=auto, min_samples_leaf=6, min_samples_split=7, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=True, max_depth=88, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=True, max_depth=88, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=True, max_depth=88, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=633; total time=   0.0s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=744; total time=  19.4s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=744; total time=  31.5s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=  14.1s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  34.4s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=800; total time=  36.6s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  11.3s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=411; total time=  11.8s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=800; total time=  21.5s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=355; total time=  15.5s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=522; total time=  14.7s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=744; total time=  29.5s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   8.4s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=  12.6s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   8.2s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=688; total time=  19.8s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=355; total time=  14.4s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=800; total time=  21.3s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  14.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=633; total time=  17.8s
# [CV] END bootstrap=False, max_depth=94, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=633; total time=  25.6s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=577; total time=  17.0s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=633; total time=  19.0s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=355; total time=  15.6s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=  14.0s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  10.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=   9.0s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=633; total time=  19.3s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=411; total time=  11.5s
# [CV] END bootstrap=True, max_depth=77, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  11.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=633; total time=  17.6s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=  21.1s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=522; total time=  20.7s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=577; total time=  16.9s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=  17.8s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=744; total time=  21.9s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=744; total time=  20.2s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=  30.1s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=577; total time=  23.8s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=744; total time=  21.2s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=633; total time=  26.1s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=577; total time=  18.1s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=688; total time=  22.6s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  41.1s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=688; total time=  30.8s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  14.6s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=411; total time=  13.1s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=  24.7s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=522; total time=  22.8s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=411; total time=  12.7s
# [CV] END bootstrap=True, max_depth=94, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=411; total time=  11.6s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=355; total time=  10.5s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=688; total time=  20.1s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=  22.7s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=577; total time=  16.7s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=800; total time=  23.0s
# [CV] END bootstrap=False, max_depth=66, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=  32.5s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=633; total time=  26.9s
# [CV] END bootstrap=False, max_depth=66, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=688; total time=  32.0s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  17.5s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=577; total time=  31.5s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=800; total time=  40.2s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=355; total time=  17.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=744; total time=  24.1s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=355; total time=  16.1s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=466; total time=  14.0s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  17.7s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=411; total time=  17.5s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=  13.6s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=522; total time=  24.7s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=577; total time=  16.8s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=800; total time=  23.0s
# [CV] END bootstrap=False, max_depth=66, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=  32.3s
# [CV] END bootstrap=False, max_depth=88, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=633; total time=  26.5s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=688; total time=  20.3s
# [CV] END bootstrap=False, max_depth=83, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=83, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=83, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  22.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=300; total time=   8.5s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=522; total time=  21.0s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=466; total time=  19.5s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=522; total time=  22.5s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=355; total time=  13.9s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=633; total time=  16.4s
# [CV] END bootstrap=False, max_depth=50, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=False, max_depth=50, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=False, max_depth=50, max_features=auto, min_samples_leaf=6, min_samples_split=8, n_estimators=355; total time=   0.0s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  12.1s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=688; total time=  19.8s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=633; total time=  21.0s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   8.2s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=744; total time=  19.8s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=355; total time=   9.7s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=800; total time=  21.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=800; total time=  25.2s
# [CV] END bootstrap=True, max_depth=66, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=633; total time=  19.7s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=577; total time=  23.9s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=688; total time=  19.2s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=9, n_estimators=355; total time=   9.8s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=633; total time=  18.0s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=633; total time=  18.5s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  16.9s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=411; total time=  17.1s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=522; total time=  21.7s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=744; total time=  31.4s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=411; total time=  17.0s
# [CV] END bootstrap=False, max_depth=94, max_features=sqrt, min_samples_leaf=3, min_samples_split=7, n_estimators=577; total time=  26.1s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=  30.5s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=  11.1s
# [CV] END bootstrap=False, max_depth=66, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=688; total time=  30.1s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=522; total time=  14.4s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  36.8s
# [CV] END bootstrap=True, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=7, n_estimators=355; total time=  10.4s
# [CV] END bootstrap=True, max_depth=83, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=577; total time=  18.6s
# [CV] END bootstrap=True, max_depth=88, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=411; total time=  11.8s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=744; total time=  32.0s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=466; total time=  19.3s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=3, min_samples_split=9, n_estimators=633; total time=  18.6s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=411; total time=  17.1s
# [CV] END bootstrap=True, max_depth=61, max_features=sqrt, min_samples_leaf=6, min_samples_split=8, n_estimators=688; total time=  18.2s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=522; total time=  21.5s
# [CV] END bootstrap=True, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=744; total time=  20.9s
# [CV] END bootstrap=False, max_depth=83, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=355; total time=  14.7s
# [CV] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=5, min_samples_split=9, n_estimators=577; total time=  24.7s
# [CV] END bootstrap=False, max_depth=77, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=355; total time=  14.9s
# [CV] END bootstrap=False, max_depth=61, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=744; total time=  30.5s
# [CV] END bootstrap=False, max_depth=72, max_features=sqrt, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=  10.7s

# %% [markdown]
# ### Conduct Grid Search Hyperparameter Tuning for training based on datasets "dvalue_all_"

# %%
    
    rf_grid=gridSearchCVdf(train_features,train_labels)
    evaluate(rf_grid, test_features, test_labels)
# Out:
# Fitting 3 folds for each of 1008 candidates, totalling 3024 fits
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=350; total time=   9.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   8.2s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=   6.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=500; total time=  13.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=250; total time=   6.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=500; total time=  13.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=350; total time=   9.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=350; total time=   9.4s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=   8.0s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   8.0s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=350; total time=   9.4s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=350; total time=   9.2s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=  12.2s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=250; total time=  10.2s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=   8.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=300; total time=  12.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=250; total time=   9.9s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=500; total time=  19.9s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   9.9s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500; total time=  19.6s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   8.3s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=350; total time=  14.3s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=350; total time=  13.5s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=  11.6s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=250; total time=   9.7s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   7.6s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  11.6s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=250; total time=   7.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=500; total time=  14.7s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=350; total time=  10.2s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=350; total time=  10.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=   8.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   7.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500; total time=  14.0s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   5.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=350; total time=   9.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=350; total time=   9.4s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   8.4s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=250; total time=   7.0s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=250; total time=  10.5s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   8.5s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=350; total time=  14.7s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=300; total time=  12.6s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=250; total time=  10.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=500; total time=  20.5s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=  10.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=500; total time=  20.7s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   7.9s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=350; total time=  14.0s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=350; total time=  13.6s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=  11.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=250; total time=   9.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   7.9s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  11.9s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=250; total time=   7.2s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=400; total time=  11.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=400; total time=  12.2s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=  11.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=500; total time=  14.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=400; total time=  11.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=250; total time=   6.9s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   5.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=350; total time=   9.7s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=350; total time=  14.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=350; total time=  14.6s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=350; total time=  14.6s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  12.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=  12.4s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   8.4s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=350; total time=  14.5s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=350; total time=  15.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=350; total time=  15.1s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=350; total time=  14.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=350; total time=  14.3s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300; total time=  11.9s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=250; total time=  10.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   6.6s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=   9.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=250; total time=   7.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   9.2s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=350; total time=  10.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=350; total time=  10.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=350; total time=  10.3s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=350; total time=  10.2s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=350; total time=   9.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=350; total time=  10.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=300; total time=   9.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   8.9s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=  13.4s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=250; total time=  11.0s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=  22.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=250; total time=  10.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   8.5s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=350; total time=  14.9s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=  13.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=  15.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  10.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=200; total time=   8.2s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  12.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=250; total time=  10.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=200; total time=   8.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=300; total time=  12.6s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=250; total time=  10.8s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=   9.2s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=250; total time=   7.6s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=  15.8s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   8.9s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   6.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=  11.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=  11.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=500; total time=  14.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   7.2s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=350; total time=   9.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   8.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   5.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=350; total time=   9.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=350; total time=   9.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=350; total time=   9.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=  12.7s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=  12.5s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=   8.4s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=  16.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  16.5s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=500; total time=  21.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=250; total time=  10.3s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   8.7s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  13.4s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  12.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   8.2s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=  16.1s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=500; total time=  20.3s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=250; total time=   8.3s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=500; total time=  16.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=   7.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   6.2s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   9.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=   9.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=400; total time=  12.3s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=500; total time=  14.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=250; total time=   7.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=500; total time=  14.0s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=250; total time=   7.0s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=500; total time=  14.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=250; total time=  10.6s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   8.4s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=350; total time=  14.9s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=350; total time=  14.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  12.5s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   8.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=350; total time=  14.5s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=350; total time=  14.6s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=350; total time=  14.5s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  12.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=250; total time=   9.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=500; total time=  19.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=250; total time=   9.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=500; total time=  20.3s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=350; total time=  10.4s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   8.8s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=300; total time=   8.7s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=350; total time=  10.2s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=   8.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=350; total time=   9.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   8.4s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=   7.0s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=500; total time=  13.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=250; total time=   6.9s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=500; total time=  13.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=250; total time=   6.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=500; total time=  13.6s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  10.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=300; total time=   8.0s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   8.2s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=350; total time=  14.3s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=350; total time=  14.3s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=350; total time=  14.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  12.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=250; total time=   9.9s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=400; total time=  16.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=200; total time=   7.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=  12.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  12.6s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=200; total time=   7.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  11.6s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=  11.4s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=200; total time=   7.6s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=350; total time=  13.6s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=350; total time=  13.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=   9.2s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=  11.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=  11.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  11.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=500; total time=  14.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=250; total time=   7.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=400; total time=  11.3s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  14.0s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=250; total time=   6.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=  14.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=250; total time=   7.0s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  13.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   8.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=  12.4s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=  10.6s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   8.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=  12.5s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=250; total time=  10.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   8.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=  12.2s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=250; total time=  10.7s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=500; total time=  20.2s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=200; total time=   8.0s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  15.8s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=  15.6s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=400; total time=  16.4s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  19.6s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=250; total time=   7.3s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=  14.9s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=250; total time=   7.2s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=500; total time=  14.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=250; total time=   6.9s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=250; total time=   6.9s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   5.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=   8.2s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   6.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500; total time=  13.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  13.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  13.2s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=500; total time=  20.4s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=  10.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=500; total time=  19.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   8.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=400; total time=  16.3s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=400; total time=  16.1s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=400; total time=  17.1s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=200; total time=   7.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  11.5s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=250; total time=   9.5s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=  19.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=250; total time=   9.5s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  15.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=350; total time=  10.2s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=300; total time=   8.7s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=400; total time=  11.6s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=400; total time=  11.1s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  13.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=350; total time=   9.8s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=350; total time=   9.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   8.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=250; total time=  10.6s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=250; total time=  10.4s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=350; total time=  14.6s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=350; total time=  14.5s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=350; total time=  14.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=  12.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   8.2s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=400; total time=  16.3s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=400; total time=  16.2s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  15.9s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  15.9s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=500; total time=  19.4s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   8.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=  15.6s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=500; total time=  14.7s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=350; total time=  10.2s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=   8.5s
# [CV] END bootstrap=True, max_depth=30, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=500; total time=  14.0s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=   7.0s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=350; total time=   9.6s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=350; total time=   9.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   8.2s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=250; total time=   6.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=500; total time=  13.5s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  10.6s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=  10.6s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=400; total time=  10.8s
# [CV] END bootstrap=True, max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   8.1s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=  12.1s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=  10.1s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=500; total time=  20.1s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=250; total time=  10.0s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=500; total time=  19.9s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=250; total time=   9.9s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=500; total time=  20.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=200; total time=   7.8s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  15.3s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=  15.2s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=400; total time=  15.3s
# [CV] END bootstrap=True, max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  19.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=250; total time=   7.2s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=  14.9s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=250; total time=   7.3s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=500; total time=  14.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   8.7s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=200; total time=   5.7s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=   8.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   8.3s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=200; total time=   5.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=350; total time=   9.5s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=350; total time=   9.6s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=300; total time=   8.2s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=25, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  13.7s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=500; total time=  21.2s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=  10.4s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=500; total time=  21.0s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=300; total time=  12.1s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   8.2s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=350; total time=  14.0s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=  12.4s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   9.9s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  20.0s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   7.9s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=350; total time=  13.7s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=350; total time=  14.0s
# [CV] END bootstrap=True, max_depth=25, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=  11.9s
# ...
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   8.9s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=400; total time=  23.6s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  12.8s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  30.4s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=350; total time=  20.7s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=400; total time=  20.2s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   6.2s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=350; total time=  10.7s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   9.3s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=   7.5s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=500; total time=  15.0s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=250; total time=   7.4s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=500; total time=  14.9s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=300; total time=   9.2s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   6.1s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  11.8s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  11.5s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=200; total time=   5.6s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=350; total time=   9.8s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   8.7s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=  13.2s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=250; total time=  10.8s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=500; total time=  22.0s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=250; total time=  11.2s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=200; total time=   8.6s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=350; total time=  15.3s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=350; total time=  15.3s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=350; total time=  15.0s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=350; total time=  15.0s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  12.6s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=  12.6s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=250; total time=  10.4s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=500; total time=  21.4s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=300; total time=   9.6s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   6.9s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=400; total time=  13.0s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   6.2s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   9.4s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=250; total time=   7.9s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=350; total time=  10.6s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=350; total time=  10.5s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=350; total time=  10.7s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=350; total time=  10.5s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=350; total time=  10.2s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=350; total time=  10.5s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=350; total time=  10.2s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=350; total time=  16.3s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=350; total time=  16.3s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=350; total time=  15.7s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  17.9s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=400; total time=  17.9s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=200; total time=   8.6s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=350; total time=  15.5s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  15.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=300; total time=  12.6s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=  12.7s
# [CV] END bootstrap=True, max_depth=40, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  14.8s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   8.9s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=  13.5s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=  11.2s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=  18.1s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=500; total time=  29.4s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=  18.6s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=400; total time=  24.4s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=200; total time=  11.4s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  23.5s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=250; total time=  14.2s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  10.9s
# [CV] END bootstrap=True, max_depth=40, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=350; total time=  14.4s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=350; total time=  10.8s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   9.9s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=300; total time=   9.1s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   5.9s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  11.3s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=400; total time=  11.6s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=500; total time=  14.5s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   7.0s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  13.9s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=  10.9s
# [CV] END bootstrap=True, max_depth=45, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=500; total time=  13.8s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=250; total time=  10.4s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   8.3s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=  12.6s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=250; total time=  10.3s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=500; total time=  20.7s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=250; total time=  10.0s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=500; total time=  20.0s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=250; total time=   9.9s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=500; total time=  20.0s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=250; total time=   9.6s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=500; total time=  19.4s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=200; total time=   7.8s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=5, min_samples_split=9, n_estimators=350; total time=  13.8s
# [CV] END bootstrap=True, max_depth=45, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=350; total time=  14.1s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=7, n_estimators=350; total time=  10.2s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=   5.8s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=  11.3s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  11.3s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=7, n_estimators=400; total time=  11.2s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=400; total time=  11.2s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=4, min_samples_split=9, n_estimators=500; total time=  13.9s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=250; total time=   6.7s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  10.7s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=400; total time=  10.8s
# [CV] END bootstrap=True, max_depth=50, max_features=2, min_samples_leaf=5, min_samples_split=9, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=200; total time=   8.5s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=7, n_estimators=500; total time=  21.0s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=200; total time=   8.3s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=9, n_estimators=400; total time=  16.4s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=  16.2s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=7, n_estimators=400; total time=  16.1s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=8, n_estimators=400; total time=  16.3s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=4, min_samples_split=9, n_estimators=500; total time=  20.8s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=250; total time=   9.7s
# [CV] END bootstrap=True, max_depth=50, max_features=3, min_samples_leaf=5, min_samples_split=7, n_estimators=400; total time=  16.6s
# {'bootstrap': True, 'max_depth': 25, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 300}
# Root Mean Squared Error: 0.19719419831751517
# R_Squared: 0.4146628676660372
# Mean Absolute Error: 0.14872970015627607

# %% [markdown]
# ### Conduct Grid Search Hyperparameter Tuning for training based on datasets "dvalue_all_"

# %%
    rf_bayes=bayesSearchCVdf(train_features,train_labels)
    evaluate(rf_bayes, test_features, test_labels)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 rf_bayes=bayesSearchCV(train_features,train_labels)
#       2 evaluate(rf_bayes, test_features, test_labels)
#
# Cell In[25], line 40, in bayesSearchCV(train_features, train_labels)
#      28 bayes_search = BayesSearchCV(
#      29     estimator=rf,
#      30     search_spaces=param_space,
#    (...)
#      36     random_state=1234
#      37 )
#      39 # train and fit
# ---> 40 bayes_search.fit(train_features, train_labels.ravel())  # ravel()convert train_labels from 2D array to 1D array
#      42 # best hyperparameters
#      43 print("Best Parameters:", bayes_search.best_params_)
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/searchcv.py:466, in BayesSearchCV.fit(self, X, y, groups, callback, **fit_params)
#     463 else:
#     464     self.optimizer_kwargs_ = dict(self.optimizer_kwargs)
# --> 466 super().fit(X=X, y=y, groups=groups, **fit_params)
#     468 # BaseSearchCV never ranked train scores,
#     469 # but apparently we used to ship this (back-compat)
#     470 if self.return_train_score:
#
# File ~/mldlTS/lib/python3.8/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/mldlTS/lib/python3.8/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/searchcv.py:512, in BayesSearchCV._run_search(self, evaluate_candidates)
#     508 while n_iter > 0:
#     509     # when n_iter < n_points points left for evaluation
#     510     n_points_adjusted = min(n_iter, n_points)
# --> 512     optim_result = self._step(
#     513         search_space, optimizer,
#     514         evaluate_candidates, n_points=n_points_adjusted
#     515     )
#     516     n_iter -= n_points
#     518     if eval_callbacks(callbacks, optim_result):
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/searchcv.py:400, in BayesSearchCV._step(self, search_space, optimizer, evaluate_candidates, n_points)
#     397 """Generate n_jobs parameters and evaluate them in parallel.
#     398 """
#     399 # get parameter values to evaluate
# --> 400 params = optimizer.ask(n_points=n_points)
#     402 # convert parameters to python native types
#     403 params = [[np.array(v).item() for v in p] for p in params]
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:395, in Optimizer.ask(self, n_points, strategy)
#     393 X = []
#     394 for i in range(n_points):
# --> 395     x = opt.ask()
#     396     X.append(x)
#     398     ti_available = "ps" in self.acq_func and len(opt.yi) > 0
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:367, in Optimizer.ask(self, n_points, strategy)
#     336 """Query point or multiple points at which objective should be evaluated.
#     337
#     338 n_points : int or None, default: None
#    (...)
#     364
#     365 """
#     366 if n_points is None:
# --> 367     return self._ask()
#     369 supported_strategies = ["cl_min", "cl_mean", "cl_max"]
#     371 if not (isinstance(n_points, int) and n_points > 0):
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:434, in Optimizer._ask(self)
#     430 if self._n_initial_points > 0 or self.base_estimator_ is None:
#     431     # this will not make a copy of `self.rng` and hence keep advancing
#     432     # our random state.
#     433     if self._initial_samples is None:
# --> 434         return self.space.rvs(random_state=self.rng)[0]
#     435     else:
#     436         # The samples are evaluated starting form initial_samples[0]
#     437         return self._initial_samples[
#     438             len(self._initial_samples) - self._n_initial_points]
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/space/space.py:900, in Space.rvs(self, n_samples, random_state)
#     897 columns = []
#     899 for dim in self.dimensions:
# --> 900     columns.append(dim.rvs(n_samples=n_samples, random_state=rng))
#     902 # Transpose
#     903 return _transpose_list_array(columns)
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/space/space.py:158, in Dimension.rvs(self, n_samples, random_state)
#     156 rng = check_random_state(random_state)
#     157 samples = self._rvs.rvs(size=n_samples, random_state=rng)
# --> 158 return self.inverse_transform(samples)
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/space/space.py:528, in Integer.inverse_transform(self, Xt)
#     523 """Inverse transform samples from the warped space back into the
#     524    original space.
#     525 """
#     526 # The concatenation of all transformed dimensions makes Xt to be
#     527 # of type float, hence the required cast back to int.
# --> 528 inv_transform = super(Integer, self).inverse_transform(Xt)
#     529 if isinstance(inv_transform, list):
#     530     inv_transform = np.array(inv_transform)
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/space/space.py:168, in Dimension.inverse_transform(self, Xt)
#     164 def inverse_transform(self, Xt):
#     165     """Inverse transform samples from the warped space back into the
#     166        original space.
#     167     """
# --> 168     return self.transformer.inverse_transform(Xt)
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/space/transformers.py:309, in Pipeline.inverse_transform(self, X)
#     307 def inverse_transform(self, X):
#     308     for transformer in self.transformers[::-1]:
# --> 309         X = transformer.inverse_transform(X)
#     310     return X
#
# File ~/mldlTS/lib/python3.8/site-packages/skopt/space/transformers.py:275, in Normalize.inverse_transform(self, X)
#     273 X_orig = X * (self.high - self.low) + self.low
#     274 if self.is_int:
# --> 275     return np.round(X_orig).astype(np.int)
#     276 return X_orig
#
# File ~/mldlTS/lib/python3.8/site-packages/numpy/__init__.py:305, in __getattr__(attr)
#     300     warnings.warn(
#     301         f"In the future `np.{attr}` will be defined as the "
#     302         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     304 if attr in __former_attrs__:
# --> 305     raise AttributeError(__former_attrs__[attr])
#     307 # Importing Tester requires importing all of UnitTest which is not a
#     308 # cheap import Since it is mainly used in test suits, we lazy import it
#     309 # here to save on the order of 10 ms of import time for most users
#     310 #
#     311 # The previous way Tester was imported also had a side effect of adding
#     312 # the full `numpy.testing` namespace
#     313 if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'int'.
# `np.int` was a deprecated alias for the builtin `int`. To avoid this error in existing code, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
